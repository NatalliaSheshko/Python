# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')#можно * и р
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'p')
plt.show()

# %%
# Формат строк fmt
# Вы также можете использовать параметр сокращенной записи строки, чтобы указать маркер.

# Этот параметр также называется fmt и записывается с помощью следующего синтаксиса:

# marker|line|color

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
#plt.plot(ypoints, 'o--r')
#plt.plot(ypoints, 'o-.r')
plt.show()


# 'r'	Red	
# 'g'	Green	
# 'b'	Blue	
# 'c'	Cyan	
# 'm'	Magenta	
# 'y'	Yellow	
# 'k'	Black	
# 'w'	White

# %%
 # lines
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'solid')
plt.show()


# 'solid' (default)	'-'	
# 'dotted'	':'	
# 'dashed'	'--'	
# 'dashdot'	'-.'	
# 'None'	'' or ' '

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
# labels
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)



# plt.grid()

plt.plot(x, y)
plt.show()

# %%
# Функция subplot() принимает три аргумента, которые описывают макет рисунка.

# Макет организован в строках и столбцах, которые представлены первым и вторым аргументами.

# Третий аргумент представляет индекс текущего графика.
# Итак, если нам нужна фигура с 2 строками и 1 столбцом 
# (что означает, что два графика будут отображаться друг над другом, а не рядом), 
# мы можем записать синтаксис следующим образом:



#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Peaches"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Peaches"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import random
import datetime
# import prettytable                  # пакет для таблицы
import matplotlib.pyplot as plt     # библиотека для графика

def BubbleSort(A):                  # сортировка пузырьком
    for i in range(len(A)):
        for j in range(len(A)-1-i):
            if A[j] > A[j+1]:
                a = A[j]
                A[j] = A[j+1]
                A[j+1] = a


def QuickSort(A, fst, lst):         # быстрая сортировка
    if fst >= lst:
        return

    #i, j = fst, lst
    pivot = A[fst]
    # pivot = A[random.randint(fst, lst)]
    first_bigger = fst+1
    while first_bigger <= lst:
        if A[first_bigger] >= pivot:
            break
        first_bigger += 1
    i = first_bigger+1
    while i <= lst:
        if A[i] < pivot:
            A[i], A[first_bigger] = A[first_bigger], A[i]
            first_bigger += 1
        i += 1

    last_smaller = first_bigger-1
    A[fst], A[last_smaller] = A[last_smaller], A[fst]
    QuickSort(A, fst, last_smaller-1)
    QuickSort(A, first_bigger, lst)

def InsertSort(A):  # сортировка вставки
    for i in range(1, len(A)):
        t = A[i]
        j = i - 1
        while j >= 0 and t < A[j]:
            A[j + 1] = A[j]
            j -= 1
        A[j + 1] = t

def ShakerSort(A):  # шейкерная сортировка
    N = len(A)
    for i in range(N // 2):
        for j in range(i, N - 1 - i):
            if A[j] > A[j + 1]:
                A[j], A[j + 1] = A[j + 1], A[j]
        for j in range(N - 2 - i, i, -1):
            if A[j] < A[j - 1]:
                A[j], A[j - 1] = A[j - 1], A[j]


# table = prettytable.PrettyTable(["Размер списка", "Время пузырька", "Время быстрой"])
x=[]
y1=[]#Пузырьковая сортировка
y2=[]#Быстрая сортировка
y3=[]#Сортировка вставки
y4=[]#Шейкерная сортировка


for N in range(1000,5001,1000):
    x.append(N)
    min=1
    max=N
    A=[]
    for i in range (N):
        A.append(int(round(random.random()*(max-min)+min)))

    #print(A)

    B = A.copy()
    # print(B)

    C = A.copy()
    D = A.copy()

    # BubbleSort(A)
    print("---")
    # print(A)

    # QuickSort(B, 0, len(B)-1)
    print("---")
    # print(B)

    t1 = datetime.datetime.now()
    BubbleSort(A)
    t2 = datetime.datetime.now()
    y1.append((t2-t1).total_seconds())
    print("Пузырьковая сортировка " +str(N)+"   заняла   "+str((t2-t1).total_seconds()) + "c")

    t3 = datetime.datetime.now()
    QuickSort(B, 0, len(B)-1)
    t4 = datetime.datetime.now()
    y2.append((t4 - t3).total_seconds())
    print("Быстрая сортировка " +str(N)+"   заняла   "+str((t4-t3).total_seconds()) + "c")
    
    t5 = datetime.datetime.now()
    InsertSort(C)
    t6 = datetime.datetime.now()
    y3.append((t6-t5).total_seconds())
    print("Сортировка вставки " +str(N)+"   заняла   "+str((t6-t5).total_seconds()) + "c")
    
    t7 = datetime.datetime.now()
    ShakerSort(D)
    t8 = datetime.datetime.now()
    y4.append((t8-t7).total_seconds())
    print("Шейкерная сортировка " +str(N)+"   заняла   "+str((t8-t7).total_seconds()) + "c")
    
    # table.add_row([str(N), str((t2-t1).total_seconds()), str((t4-t3).total_seconds())])
# print(table)

plt.plot(x, y1, "r", label = "сортировка пузырьком")
plt.plot(x, y2, "g", label = "быстрая сортировка")
plt.plot(x, y3, "b", label = "сортировка вставки")
plt.plot(x, y4, "m", label = "шейкерная сортировка")

#Добавьте заголовок графика и подписи для осей
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("График сортировок", fontdict = font1)
plt.xlabel("Кол-во элементов, шт.", fontdict = font2)
plt.ylabel("Время, сек.", fontdict = font2)

plt.legend()
plt.show()

#Создайте точечный график для сортировок
plt.title("Точечный график сортировок", fontdict = font1)
plt.plot(x, y1, 'o', label = "сортировка пузырьком")
plt.plot(x, y2, '*', label = "быстрая сортировка")
plt.plot(x, y3, 'p', label = "сортировка вставки")
plt.plot(x, y4, 'o', label = "шейкерная сортировка")
plt.legend()
plt.show()

#Создайте BarPlot для сортировок
plt.figure(figsize=(10,6))
width = 150
plt.bar([p - width for p in x], y1, width = width, color = "hotpink", label = "сортировка пузырьком")
plt.bar(x, y2, width = width, color = "blue", label = "быстрая сортировка")
plt.bar([p + width for p in x], y3, width = width, color = "yellow", label = "сортировка вставки")
plt.bar([p + 2*width for p in x], y1, width = width, color = "orange", label = "шейкерная сортировка")

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Столбчатый график сортировок", fontdict = font1)
plt.xlabel("Кол-во элементов, шт.", fontdict = font2)
plt.ylabel("Время, сек.", fontdict = font2)

plt.legend()
plt.show()

#Разделите сортировки на отдельные графики
font3 = {'family':'serif','color':'blue','size':10}
font4 = {'family':'serif','color':'blue','size':7}

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title("Cортировка пузырьком", fontdict = font3)
plt.xlabel("Кол-во элементов, шт.", fontdict = font4)
plt.ylabel("Время, сек.", fontdict = font4)

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title("Быстрая сортировка", fontdict = font3)
plt.xlabel("Кол-во элементов, шт.", fontdict = font4)
plt.ylabel("Время, сек.", fontdict = font4)

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title("Сортировка вставки", fontdict = font3)
plt.xlabel("Кол-во элементов, шт.", fontdict = font4)
plt.ylabel("Время, сек.", fontdict = font4)

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title("Шейкерная сортировка", fontdict = font3)
plt.xlabel("Кол-во элементов, шт.", fontdict = font4)
plt.ylabel("Время, сек.", fontdict = font4)

plt.subplots_adjust(hspace = 0.5)
plt.subplots_adjust(wspace = 0.5)

plt.show()
# Out:
# ---
# ---
# Пузырьковая сортировка 1000   заняла   0.055c
# Быстрая сортировка 1000   заняла   0.001c
# Сортировка вставки 1000   заняла   0.026c
# Шейкерная сортировка 1000   заняла   0.062c
# ---
# ---
# Пузырьковая сортировка 2000   заняла   0.244c
# Быстрая сортировка 2000   заняла   0.003c
# Сортировка вставки 2000   заняла   0.109c
# Шейкерная сортировка 2000   заняла   0.259c
# ---
# ---
# Пузырьковая сортировка 3000   заняла   0.572c
# Быстрая сортировка 3000   заняла   0.006c
# Сортировка вставки 3000   заняла   0.265c
# Шейкерная сортировка 3000   заняла   0.606c
# ---
# ---
# Пузырьковая сортировка 4000   заняла   1.041c
# Быстрая сортировка 4000   заняла   0.006c
# Сортировка вставки 4000   заняла   0.446c
# Шейкерная сортировка 4000   заняла   1.049c
# ---
# ---
# Пузырьковая сортировка 5000   заняла   1.597c
# Быстрая сортировка 5000   заняла   0.008c
# Сортировка вставки 5000   заняла   0.692c
# Шейкерная сортировка 5000   заняла   1.62c

# %% [markdown]
# ## Задача для самостоятельного разбора ##

# %% [markdown]
# 1. Написать алгоритмы сортировок insert и shaker по псевдокоду
# 2. Вставить их в код выше, вывести время выполнения сортировки(как для пузырька и быстрой сортирововок) и добавить результат в график
# 3. Добавьте заголовок графика и подписи для осей
# 5. Создайте точечный график для сортировок
# 6. Создайте BarPlot для сортировок
# 7. Разделите сортировки на отдельные графики
